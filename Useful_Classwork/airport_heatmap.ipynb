# %%
import gmaps
import pandas as pd

# Google developer API key
from config import gkey

# Configure gmaps
gmaps.configure(api_key=gkey)

# %%
# Create aiport dataframe
airport_df = pd.read_csv('../Resources/Airport_Output.csv')
airport_df.dropna()
airport_df.head(30)
# Out:
#     Unnamed: 0           City                 State        Lat         Lng  \
# 0            0  New York City              New York  40.712775  -74.005973
# 1            1    Los Angeles            California  34.052234 -118.243685
# 2            2        Chicago              Illinois  41.878114  -87.629798
# 3            3        Houston                 Texas  29.760427  -95.369803
# 4            4   Philadelphia          Pennsylvania  39.952584  -75.165222
# 5            5        Phoenix               Arizona  33.448377 -112.074037
# 6            6    San Antonio                 Texas  29.424122  -98.493628
# 7            7      San Diego            California  32.715738 -117.161084
# 8            8         Dallas                 Texas  32.776664  -96.796988
# 9            9       San Jose            California  37.338208 -121.886329
# 10          10         Austin                 Texas  30.267153  -97.743061
# 11          11   Jacksonville               Florida  30.332184  -81.655651
# 12          12  San Francisco            California  37.774929 -122.419415
# 13          13   Indianapolis               Indiana  39.768403  -86.158068
# 14          14       Columbus                  Ohio  39.961176  -82.998794
# 15          15     Fort Worth                 Texas  32.755488  -97.330766
# 16          16      Charlotte        North Carolina  35.227087  -80.843127
# 17          17        Seattle            Washington  47.606209 -122.332071
# 18          18         Denver              Colorado  39.739236 -104.990251
# 19          19        El Paso                 Texas  31.761878 -106.485022
# 20          20        Detroit              Michigan  42.331427  -83.045754
# 21          21     Washington  District of Columbia  38.907192  -77.036871
# 22          22         Boston         Massachusetts  42.360083  -71.058880
# 23          23        Memphis             Tennessee  35.149534  -90.048980
# 24          24      Nashville             Tennessee  36.162664  -86.781602
# 25          25       Portland                Oregon  45.523062 -122.676481
# 26          26  Oklahoma City              Oklahoma  35.467560  -97.516428
# 27          27      Las Vegas                Nevada  36.169941 -115.139830
# 28          28      Baltimore              Maryland  39.290385  -76.612189
# 29          29     Louisville              Kentucky  38.252665  -85.758456
#
#                                          Airport Name  \
# 0                Newark Liberty International Airport
# 1                   Los Angeles International Airport
# 2                        O'Hare International Airport
# 3                            William P. Hobby Airport
# 4                  Philadelphia International Airport
# 5            Phoenix Sky Harbor International Airport
# 6                   San Antonio International Airport
# 7                     San Diego International Airport
# 8             Dallas/Fort Worth International Airport
# 9                 San Francisco International Airport
# 10             Austin-Bergstrom International Airport
# 11                 Jacksonville International Airport
# 12                San Francisco International Airport
# 13                 Indianapolis International Airport
# 14          John Glenn Columbus International Airport
# 15            Dallas/Fort Worth International Airport
# 16            Charlotte Douglas International Airport
# 17               Seattle-Tacoma International Airport
# 18                       Denver International Airport
# 19                      El Paso International Airport
# 20          Detroit Metropolitan Wayne County Airport
# 21                       Dulles International Airport
# 22                 Boston Logan International Airport
# 23                      Memphis International Airport
# 24                    Nashville International Airport
# 25                     Portland International Airport
# 26                          Will Rogers World Airport
# 27                     McCarran International Airport
# 28  Baltimore/Washington International Thurgood Ma...
# 29                   Louisville International Airport
#
#                                      Airport Address  Airport Rating
# 0                              3 Brewster Rd, Newark             3.2
# 1                           1 World Way, Los Angeles             3.5
# 2                        10000 W O'Hare Ave, Chicago             3.6
# 3                         7800 Airport Blvd, Houston             4.0
# 4                   8000 Essington Ave, Philadelphia             3.3
# 5                    3400 E Sky Harbor Blvd, Phoenix             3.9
# 6                     9800 Airport Blvd, San Antonio             4.0
# 7                        3225 N Harbor Dr, San Diego             3.9
# 8                      2400 Aviation Dr, DFW Airport             3.8
# 9                                      San Francisco             4.1
# 10                    3600 Presidential Blvd, Austin             4.0
# 11              2400 Yankee Clipper Dr, Jacksonville             4.2
# 12                                     San Francisco             4.1
# 13  7800 Col. H. Weir Cook Memorial Dr, Indianapolis             4.3
# 14              4600 International Gateway, Columbus             3.9
# 15                     2400 Aviation Dr, DFW Airport             3.8
# 16              5501 Josh Birmingham Pkwy, Charlotte             3.5
# 17                 17801 International Blvd, Seattle             3.9
# 18                            8500 Peña Blvd, Denver             4.0
# 19                          6701 Convair Rd, El Paso             4.1
# 20                                           Detroit             4.1
# 21                            1 Saarinen Cir, Dulles             3.9
# 22                           1 Harborside Dr, Boston             3.9
# 23                       2491 Winchester Rd, Memphis             3.6
# 24                          1 Terminal Dr, Nashville             4.1
# 25                     7000 NE Airport Way, Portland             4.5
# 26                   7100 Terminal Dr, Oklahoma City             4.2
# 27                 5757 Wayne Newton Blvd, Las Vegas             3.9
# 28                                         Baltimore             4.0
# 29                       600 Terminal Dr, Louisville             4.0

# %%
# Store latitude and longitude in locations
locations = airport_df[["Lat", "Lng"]]

# Fill NaN values and convert to float
rating = airport_df["Airport Rating"].astype(float)

# %%
# Plot Heatmap
fig = gmaps.figure()

# Create heat layer
heat_layer = gmaps.heatmap_layer(locations, weights=rating, 
                                 dissipating=False, max_intensity=10,
                                 point_radius=1)


# Add layer
fig.add_layer(heat_layer)

# Display figure
fig

# %% [markdown]
# ![08-Airport_Heatmap.png](../Images/08-Airport_Heatmap.png)

# %%
# BONUS
# Plost as a Hybrid map
fig = gmaps.figure(map_type="HYBRID")

# Create heat layer
heat_layer = gmaps.heatmap_layer(locations, weights=rating, 
                                 dissipating=False, max_intensity=10,
                                 point_radius=1)

fig.add_layer(heat_layer)
fig

# %% [markdown]
# ![08-Hybrid_Map.png](../Images/08-Hybrid_Map.png)

# %%
# BONUS
# Plot as a Terrain map
fig = gmaps.figure(map_type="TERRAIN")

# Create heat layer
heat_layer = gmaps.heatmap_layer(locations, weights=rating, 
                                 dissipating=False, max_intensity=10,
                                 point_radius=1)

fig.add_layer(heat_layer)
fig

# %% [markdown]
# ![08-Terrain_Map.png](../Images/08-Terrain_Map.png)
